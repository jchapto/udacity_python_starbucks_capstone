# %%
import pandas as pd
import numpy as np
import math
import json
% matplotlib inline

from matplotlib import pyplot as plt

# read in the json files
portfolio = pd.read_json('data/portfolio.json', orient='records', lines=True)
profile = pd.read_json('data/profile.json', orient='records', lines=True)
transcript = pd.read_json('data/transcript.json', orient='records', lines=True)

# %%
portfolio
# Out:
#                        channels  difficulty  duration  \
# 0       [email, mobile, social]          10         7
# 1  [web, email, mobile, social]          10         5
# 2          [web, email, mobile]           0         4
# 3          [web, email, mobile]           5         7
# 4                  [web, email]          20        10
# 5  [web, email, mobile, social]           7         7
# 6  [web, email, mobile, social]          10        10
# 7       [email, mobile, social]           0         3
# 8  [web, email, mobile, social]           5         5
# 9          [web, email, mobile]          10         7
#
#                                  id     offer_type  reward
# 0  ae264e3637204a6fb9bb56bc8210ddfd           bogo      10
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0           bogo      10
# 2  3f207df678b143eea3cee63160fa8bed  informational       0
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo       5
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       discount       5
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2       discount       3
# 6  fafdcd668e3743c1bb461111dcafc2a4       discount       2
# 7  5a8bc65990b245e5a138643cd4eb9837  informational       0
# 8  f19421c1d4aa40978ebb69ca19b0e20d           bogo       5
# 9  2906b810c7d4411798c6938adc9daaa5       discount       2

# %%
profile
# Out:
#        age  became_member_on gender                                id  \
# 0      118          20170212   None  68be06ca386d4c31939f3a4f0e3dd783
# 1       55          20170715      F  0610b486422d4921ae7d2bf64640c50b
# 2      118          20180712   None  38fe809add3b4fcf9315a9694bb96ff5
# 3       75          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 4      118          20170804   None  a03223e636434f42ac4c3df47e8bac43
# 5       68          20180426      M  e2127556f4f64592b11af22de27a7932
# 6      118          20170925   None  8ec6ce2a7e7949b1bf142def7d0e0586
# 7      118          20171002   None  68617ca6246f4fbc85e91a2a49552598
# 8       65          20180209      M  389bc3fa690240e798340f5a15918d5c
# 9      118          20161122   None  8974fc5686fe429db53ddde067b88302
# 10     118          20170824   None  c4863c7985cf408faee930f111475da3
# 11     118          20150919   None  148adfcaa27d485b82f323aaaad036bd
# 12      58          20171111      M  2eeac8d8feae4a8cad5a6af0499a211d
# 13      61          20170911      F  aa4862eba776480b8bb9c68455b8c2e1
# 14      26          20140213      M  e12aeaf2d47d42479ea1c4ac3d8286c6
# 15      62          20160211      F  31dda685af34476cad5bc968bdb01c53
# 16      49          20141113      M  62cf5e10845442329191fc246e7bcea3
# 17     118          20170801   None  744d603ef08c4f33af5a61c8c7628d1c
# 18      57          20171231      M  6445de3b47274c759400cd68131d91b4
# 19      61          20180501      F  a448667f336b42c9a66fc5ffd5d73772
# 20      40          20160504      F  440cf1fd7580490c971d8c651ed962af
# 21      64          20170909      M  4b0da7e80e5945209a1fdddfe813dbe0
# 22      78          20170616      F  c27e0d6ab72c455a8bb66d980963de60
# 23     118          20170907   None  2b826eba31074a059d63b0ae8f50b7d5
# 24      42          20130811      M  f806632c011441378d4646567f357a21
# 25      56          20180428      F  d058f73bf8674a26a95227db098147b1
# 26     118          20170330   None  65aba5c617294649aeb624da249e1ee5
# 27      33          20170926      F  c6c9884912c645429f3333f912b55f44
# 28      46          20170911      F  7429a044884842d6862f516c38b1156f
# 29      59          20150121      M  ebe7ef46ea6f4963a7dd49f501b26779
# ...    ...               ...    ...                               ...
# 16970   67          20151107      M  a2e6029e17b6466187a40b66e333a73e
# 16971   52          20180522      F  6e71b66784844d1ab8376ac8ab096d4b
# 16972   44          20170119      F  e2fd53ed790240c586b3188f23542cca
# 16973   30          20151012      M  08eb126ad33f447ca3ad076482445c05
# 16974   59          20160113      F  f88e91a11d8f405b9a47ad3741415b83
# 16975   61          20171231      F  1b4df4b48bf64727a4c445909aea1251
# 16976   39          20160921      F  122c0c2a3c2540848f8c3fdc37e97639
# 16977  118          20160609   None  eb7dd979f4644052a5c401a01f129132
# 16978   29          20170220      F  54bead4179c44b71acc4e8398181d183
# 16979   63          20130922      F  a00058cf10334a308c68e7631c529907
# 16980  118          20160901   None  5c686d09ca4d475a8f750f2ba07e0440
# 16981   84          20160629      M  1966fa40d2f84620b2b1b9b64f8e0209
# 16982  118          20160415   None  d9ca82f550ac4ee58b6299cf1e5c824a
# 16983   72          20150404      F  ff737c250d2343729ade04c4f6eb1001
# 16984   75          20160716      F  392d23b2c958493197f647bedfe4f418
# 16985   26          20180619      M  97ee6e7a12fe4064b260fa48bdd0330f
# 16986   59          20170731      F  bf3069b178fe40d789dd027901bc406b
# 16987   57          20160709      M  76ddbd6576844afe811f1a3c0fbb5bec
# 16988   64          20180104      M  f653cf2d8bba42d0a53c2937ee2e5893
# 16989  118          20180305   None  ca45ee1883624304bac1e4c8a114f045
# 16990   70          20160310      F  79edb810789c447e8d212a324b44cc16
# 16991  118          20160116   None  a9a20fa8b5504360beb4e7c8712f8306
# 16992   21          20170917      F  400d0536e8794cbb855b0d882d67cbda
# 16993   60          20180505      M  cb23b66c56f64b109d673d5e56574529
# 16994  118          20151211   None  c02b10e8752c4d8e9b73f918558531f7
# 16995   45          20180604      F  6d5f3a774f3d4714ab0c092238f3a1d7
# 16996   61          20180713      M  2cb4f97358b841b9a9773a7aa05a9d77
# 16997   49          20170126      M  01d26f638c274aa0b965d24cefe3183f
# 16998   83          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 16999   62          20170722      F  e4052622e5ba45a8b96b59aba68cf068
#
#          income
# 0           NaN
# 1      112000.0
# 2           NaN
# 3      100000.0
# 4           NaN
# 5       70000.0
# 6           NaN
# 7           NaN
# 8       53000.0
# 9           NaN
# 10          NaN
# 11          NaN
# 12      51000.0
# 13      57000.0
# 14      46000.0
# 15      71000.0
# 16      52000.0
# 17          NaN
# 18      42000.0
# 19      40000.0
# 20      71000.0
# 21     100000.0
# 22      71000.0
# 23          NaN
# 24      69000.0
# 25      88000.0
# 26          NaN
# 27      52000.0
# 28      59000.0
# 29      41000.0
# ...         ...
# 16970   94000.0
# 16971   75000.0
# 16972   51000.0
# 16973   57000.0
# 16974   71000.0
# 16975   81000.0
# 16976   54000.0
# 16977       NaN
# 16978   58000.0
# 16979   52000.0
# 16980       NaN
# 16981   93000.0
# 16982       NaN
# 16983   65000.0
# 16984   78000.0
# 16985   55000.0
# 16986   63000.0
# 16987   40000.0
# 16988   51000.0
# 16989       NaN
# 16990   39000.0
# 16991       NaN
# 16992   72000.0
# 16993  113000.0
# 16994       NaN
# 16995   54000.0
# 16996   72000.0
# 16997   73000.0
# 16998   50000.0
# 16999   82000.0
#
# [17000 rows x 5 columns]

# %%
transcript
# Out:
#                   event                            person  time  \
# 0        offer received  78afa995795e4d85b5d9ceeca43f5fef     0
# 1        offer received  a03223e636434f42ac4c3df47e8bac43     0
# 2        offer received  e2127556f4f64592b11af22de27a7932     0
# 3        offer received  8ec6ce2a7e7949b1bf142def7d0e0586     0
# 4        offer received  68617ca6246f4fbc85e91a2a49552598     0
# 5        offer received  389bc3fa690240e798340f5a15918d5c     0
# 6        offer received  c4863c7985cf408faee930f111475da3     0
# 7        offer received  2eeac8d8feae4a8cad5a6af0499a211d     0
# 8        offer received  aa4862eba776480b8bb9c68455b8c2e1     0
# 9        offer received  31dda685af34476cad5bc968bdb01c53     0
# 10       offer received  744d603ef08c4f33af5a61c8c7628d1c     0
# 11       offer received  3d02345581554e81b7b289ab5e288078     0
# 12       offer received  4b0da7e80e5945209a1fdddfe813dbe0     0
# 13       offer received  c27e0d6ab72c455a8bb66d980963de60     0
# 14       offer received  d53717f5400c4e84affdaeda9dd926b3     0
# 15       offer received  f806632c011441378d4646567f357a21     0
# 16       offer received  d058f73bf8674a26a95227db098147b1     0
# 17       offer received  65aba5c617294649aeb624da249e1ee5     0
# 18       offer received  ebe7ef46ea6f4963a7dd49f501b26779     0
# 19       offer received  1e9420836d554513ab90eba98552d0a9     0
# 20       offer received  868317b9be554cb18e50bc68484749a2     0
# 21       offer received  f082d80f0aac47a99173ba8ef8fc1909     0
# 22       offer received  102e9454054946fda62242d2e176fdce     0
# 23       offer received  4beeb3ed64dd4898b0edf2f6b67426d3     0
# 24       offer received  9f30b375d7bd4c62a884ffe7034e09ee     0
# 25       offer received  25c906289d154b66bf579693f89481c9     0
# 26       offer received  6e014185620b49bd98749f728747572f     0
# 27       offer received  02c083884c7d45b39cc68e1314fec56c     0
# 28       offer received  c0d210398dee4a0895b24444a5fcd1d2     0
# 29       offer received  8be4463721e14d7fa600686bf8c8b2ed     0
# ...                 ...                               ...   ...
# 306504      transaction  8524d450673b4c24869b6c94380006de   714
# 306505      transaction  b895c57e8cd047a8872ce02aa54759d6   714
# 306506  offer completed  b895c57e8cd047a8872ce02aa54759d6   714
# 306507     offer viewed  8dda575c2a1d44b9ac8e8b07b93d1f8e   714
# 306508      transaction  8431c16f8e1d440880db371a68f82dd0   714
# 306509  offer completed  8431c16f8e1d440880db371a68f82dd0   714
# 306510      transaction  ba620885e51c4b0ea64a4f61daad494f   714
# 306511      transaction  a1a8f40407c444cc848468275308958a   714
# 306512      transaction  8d80970192fa496f99d6b45c470a4b60   714
# 306513      transaction  bde275066f3c4fa0bff3093e3b866a2c   714
# 306514      transaction  f1e4fd36e5a0446f83861308bddf6945   714
# 306515      transaction  0b64be3b241c4407a5c9a71781173829   714
# 306516      transaction  86d03d35d7e0434b935e7743e83be3a0   714
# 306517      transaction  3408fd05c781401f8442fb6dbaaea9c7   714
# 306518      transaction  1593d617fac246ef8e50dbb0ffd77f5f   714
# 306519      transaction  f1b31d07b5d84f69a2d5f1d07843989e   714
# 306520      transaction  2ce987015ec0404a97ba333e8e814090   714
# 306521      transaction  2e33545f0a764d27b2ccff95fc8d72c4   714
# 306522      transaction  d1c4500ace2e45e9a45d3cd2fccac8d8   714
# 306523      transaction  b65affd9e07346a1906364a396950e3d   714
# 306524      transaction  d613ca9c59dd42f497bdbf6178da54a7   714
# 306525      transaction  eec70ab28af74a22a4aeb889c0317944   714
# 306526      transaction  24f56b5e1849462093931b164eb803b5   714
# 306527  offer completed  24f56b5e1849462093931b164eb803b5   714
# 306528      transaction  5ca2620962114246ab218fc648eb3934   714
# 306529      transaction  b3a1272bc9904337b331bf348c3e8c17   714
# 306530      transaction  68213b08d99a4ae1b0dcb72aebd9aa35   714
# 306531      transaction  a00058cf10334a308c68e7631c529907   714
# 306532      transaction  76ddbd6576844afe811f1a3c0fbb5bec   714
# 306533      transaction  c02b10e8752c4d8e9b73f918558531f7   714
#
#                                                     value
# 0        {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 1        {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 2        {'offer id': '2906b810c7d4411798c6938adc9daaa5'}
# 3        {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}
# 4        {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}
# 5        {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}
# 6        {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}
# 7        {'offer id': '3f207df678b143eea3cee63160fa8bed'}
# 8        {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 9        {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 10       {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 11       {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 12       {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}
# 13       {'offer id': '3f207df678b143eea3cee63160fa8bed'}
# 14       {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 15       {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}
# 16       {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 17       {'offer id': '2906b810c7d4411798c6938adc9daaa5'}
# 18       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 19       {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}
# 20       {'offer id': '2906b810c7d4411798c6938adc9daaa5'}
# 21       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 22       {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}
# 23       {'offer id': '2906b810c7d4411798c6938adc9daaa5'}
# 24       {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}
# 25       {'offer id': '2906b810c7d4411798c6938adc9daaa5'}
# 26       {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}
# 27       {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}
# 28       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 29       {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}
# ...                                                   ...
# 306504                                   {'amount': 4.89}
# 306505                                   {'amount': 4.48}
# 306506  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...
# 306507   {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 306508                                   {'amount': 1.19}
# 306509  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...
# 306510                                  {'amount': 14.31}
# 306511                                   {'amount': 2.37}
# 306512                                   {'amount': 6.92}
# 306513                                  {'amount': 12.73}
# 306514                                    {'amount': 8.2}
# 306515                                    {'amount': 2.6}
# 306516                                    {'amount': 9.2}
# 306517                                   {'amount': 11.7}
# 306518                                  {'amount': 40.67}
# 306519                                  {'amount': 31.13}
# 306520                     {'amount': 1.6400000000000001}
# 306521                                  {'amount': 17.35}
# 306522                                   {'amount': 4.42}
# 306523                                  {'amount': 18.35}
# 306524                                  {'amount': 25.14}
# 306525                                  {'amount': 43.58}
# 306526                                  {'amount': 22.64}
# 306527  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...
# 306528                                    {'amount': 2.2}
# 306529                     {'amount': 1.5899999999999999}
# 306530                                   {'amount': 9.53}
# 306531                                   {'amount': 3.61}
# 306532                     {'amount': 3.5300000000000002}
# 306533                                   {'amount': 4.05}
#
# [306534 rows x 4 columns]

# %%
transcript.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306534 entries, 0 to 306533
# Data columns (total 4 columns):
# event     306534 non-null object
# person    306534 non-null object
# time      306534 non-null int64
# value     306534 non-null object
# dtypes: int64(1), object(3)
# memory usage: 9.4+ MB

# %%
# Types of events in the transcript dataset
transcript.event.value_counts()
# Out:
# transaction        138953
# offer received      76277
# offer viewed        57725
# offer completed     33579
# Name: event, dtype: int64

# %%
# Create a bar graph of the transcript dataset's quantitative columns to explore offer characteristics
fig = plt.figure()
transcript.event.value_counts().plot.bar(figsize=(7, 7), 
                                         title="Event Type Frequency")

fig = plt.figure()
transcript.event.value_counts().plot.pie(figsize=(7, 7), 
                                       title="Event Type Pie Chart", 
                                       autopct='%.1f%%', 
                                       shadow=True)

# %%
# See list of dictionary keys in the value column. Is 'offer_id' the only entry?
valueKeys = transcript.value.apply(lambda x: str(list(x.keys())))

# %%
# Cross reference value keys with event types to determine which value keys align with which event types.
pd.crosstab(valueKeys, transcript['event'])
# Out:
# event                   offer completed  offer received  offer viewed  \
# value
# ['amount']                            0               0             0
# ['offer id']                          0           76277         57725
# ['offer_id', 'reward']            33579               0             0
#
# event                   transaction
# value
# ['amount']                   138953
# ['offer id']                      0
# ['offer_id', 'reward']            0

# %%
# View examples of successfully completed offers
transcript[transcript.event == 'offer completed'].head(10)
# Out:
#                  event                            person  time  \
# 12658  offer completed  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f     0
# 12672  offer completed  fe97aa22dd3e48c8b143116a8403dd52     0
# 12679  offer completed  629fc02d56414d91bca360decdfa9288     0
# 12692  offer completed  676506bad68e4161b9bbaffeb039626b     0
# 12697  offer completed  8f7dd3b2afe14c078eb4f6e6fe4ba97d     0
# 12717  offer completed  227f2d69e46a4899b70d48182822cff6     0
# 12721  offer completed  bb0f25e23a4c4de6a645527c275cd594     0
# 12744  offer completed  d72d201be5794279aa716d8ad82b8d90     0
# 12764  offer completed  73ffefd41e9a4ca3ab26b2b3697c6eb7     0
# 12767  offer completed  3e621194f72e40d7a0b695ee9b7c38b7     0
#
#                                                    value
# 12658  {'offer_id': '2906b810c7d4411798c6938adc9daaa5...
# 12672  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...
# 12679  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...
# 12692  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd...
# 12697  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0...
# 12717  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0...
# 12721  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2...
# 12744  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d...
# 12764  {'offer_id': '2906b810c7d4411798c6938adc9daaa5...
# 12767  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0...

# %%
# View examples of a randomly chosen customer
transcript[transcript.person == 'bb0f25e23a4c4de6a645527c275cd594']
# Out:
#                   event                            person  time  \
# 317      offer received  bb0f25e23a4c4de6a645527c275cd594     0
# 12720       transaction  bb0f25e23a4c4de6a645527c275cd594     0
# 12721   offer completed  bb0f25e23a4c4de6a645527c275cd594     0
# 40812      offer viewed  bb0f25e23a4c4de6a645527c275cd594    96
# 52288       transaction  bb0f25e23a4c4de6a645527c275cd594   162
# 53492    offer received  bb0f25e23a4c4de6a645527c275cd594   168
# 74855      offer viewed  bb0f25e23a4c4de6a645527c275cd594   186
# 97732       transaction  bb0f25e23a4c4de6a645527c275cd594   264
# 97733   offer completed  bb0f25e23a4c4de6a645527c275cd594   264
# 150932   offer received  bb0f25e23a4c4de6a645527c275cd594   408
# 163478     offer viewed  bb0f25e23a4c4de6a645527c275cd594   408
# 184965      transaction  bb0f25e23a4c4de6a645527c275cd594   450
# 184966  offer completed  bb0f25e23a4c4de6a645527c275cd594   450
# 193250      transaction  bb0f25e23a4c4de6a645527c275cd594   474
# 201883   offer received  bb0f25e23a4c4de6a645527c275cd594   504
# 221968     offer viewed  bb0f25e23a4c4de6a645527c275cd594   516
# 232934      transaction  bb0f25e23a4c4de6a645527c275cd594   540
# 232935  offer completed  bb0f25e23a4c4de6a645527c275cd594   540
# 245438   offer received  bb0f25e23a4c4de6a645527c275cd594   576
# 262223     offer viewed  bb0f25e23a4c4de6a645527c275cd594   582
# 291554      transaction  bb0f25e23a4c4de6a645527c275cd594   654
# 291555  offer completed  bb0f25e23a4c4de6a645527c275cd594   654
# 300686      transaction  bb0f25e23a4c4de6a645527c275cd594   690
#
#                                                     value
# 317      {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}
# 12720                                   {'amount': 28.08}
# 12721   {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2...
# 40812    {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}
# 52288                                   {'amount': 21.62}
# 53492    {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 74855    {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 97732                                   {'amount': 35.95}
# 97733   {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...
# 150932   {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 163478   {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 184965                                  {'amount': 25.18}
# 184966  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7...
# 193250                                   {'amount': 24.4}
# 201883   {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}
# 221968   {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}
# 232934                                  {'amount': 19.46}
# 232935  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd...
# 245438   {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}
# 262223   {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}
# 291554                                  {'amount': 17.25}
# 291555  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2...
# 300686                                  {'amount': 16.96}

# %% [markdown]
# Need to figure out how to make list of whether each offer is viewed and completed. Figure out the resulting transaction amount.
#
# Loop through each person to analyze transactions

# %%
def trancriptTransform(transcript):
  
  transcript = transcript.join(pd.DataFrame.from_records(transcript.pop('value')))
  transcript.offer_id.update(transcript.pop('offer id'))

  # Rename 'if' to 'customer_id'
  transcript.rename(columns={'person': 'customer_id'}, inplace=True)
  
  # Convert 'time' from hours to days
  transcript['time_days'] = transcript['time'] / 24

  # Drop the time column
  transcript.drop(['time'], axis=1, inplace=True)

  return transcript

# %%
transcript = trancriptTransform(transcript)
transcript
# Out:
#                   event                       customer_id  amount  \
# 0        offer received  78afa995795e4d85b5d9ceeca43f5fef     NaN
# 1        offer received  a03223e636434f42ac4c3df47e8bac43     NaN
# 2        offer received  e2127556f4f64592b11af22de27a7932     NaN
# 3        offer received  8ec6ce2a7e7949b1bf142def7d0e0586     NaN
# 4        offer received  68617ca6246f4fbc85e91a2a49552598     NaN
# 5        offer received  389bc3fa690240e798340f5a15918d5c     NaN
# 6        offer received  c4863c7985cf408faee930f111475da3     NaN
# 7        offer received  2eeac8d8feae4a8cad5a6af0499a211d     NaN
# 8        offer received  aa4862eba776480b8bb9c68455b8c2e1     NaN
# 9        offer received  31dda685af34476cad5bc968bdb01c53     NaN
# 10       offer received  744d603ef08c4f33af5a61c8c7628d1c     NaN
# 11       offer received  3d02345581554e81b7b289ab5e288078     NaN
# 12       offer received  4b0da7e80e5945209a1fdddfe813dbe0     NaN
# 13       offer received  c27e0d6ab72c455a8bb66d980963de60     NaN
# 14       offer received  d53717f5400c4e84affdaeda9dd926b3     NaN
# 15       offer received  f806632c011441378d4646567f357a21     NaN
# 16       offer received  d058f73bf8674a26a95227db098147b1     NaN
# 17       offer received  65aba5c617294649aeb624da249e1ee5     NaN
# 18       offer received  ebe7ef46ea6f4963a7dd49f501b26779     NaN
# 19       offer received  1e9420836d554513ab90eba98552d0a9     NaN
# 20       offer received  868317b9be554cb18e50bc68484749a2     NaN
# 21       offer received  f082d80f0aac47a99173ba8ef8fc1909     NaN
# 22       offer received  102e9454054946fda62242d2e176fdce     NaN
# 23       offer received  4beeb3ed64dd4898b0edf2f6b67426d3     NaN
# 24       offer received  9f30b375d7bd4c62a884ffe7034e09ee     NaN
# 25       offer received  25c906289d154b66bf579693f89481c9     NaN
# 26       offer received  6e014185620b49bd98749f728747572f     NaN
# 27       offer received  02c083884c7d45b39cc68e1314fec56c     NaN
# 28       offer received  c0d210398dee4a0895b24444a5fcd1d2     NaN
# 29       offer received  8be4463721e14d7fa600686bf8c8b2ed     NaN
# ...                 ...                               ...     ...
# 306504      transaction  8524d450673b4c24869b6c94380006de    4.89
# 306505      transaction  b895c57e8cd047a8872ce02aa54759d6    4.48
# 306506  offer completed  b895c57e8cd047a8872ce02aa54759d6     NaN
# 306507     offer viewed  8dda575c2a1d44b9ac8e8b07b93d1f8e     NaN
# 306508      transaction  8431c16f8e1d440880db371a68f82dd0    1.19
# 306509  offer completed  8431c16f8e1d440880db371a68f82dd0     NaN
# 306510      transaction  ba620885e51c4b0ea64a4f61daad494f   14.31
# 306511      transaction  a1a8f40407c444cc848468275308958a    2.37
# 306512      transaction  8d80970192fa496f99d6b45c470a4b60    6.92
# 306513      transaction  bde275066f3c4fa0bff3093e3b866a2c   12.73
# 306514      transaction  f1e4fd36e5a0446f83861308bddf6945    8.20
# 306515      transaction  0b64be3b241c4407a5c9a71781173829    2.60
# 306516      transaction  86d03d35d7e0434b935e7743e83be3a0    9.20
# 306517      transaction  3408fd05c781401f8442fb6dbaaea9c7   11.70
# 306518      transaction  1593d617fac246ef8e50dbb0ffd77f5f   40.67
# 306519      transaction  f1b31d07b5d84f69a2d5f1d07843989e   31.13
# 306520      transaction  2ce987015ec0404a97ba333e8e814090    1.64
# 306521      transaction  2e33545f0a764d27b2ccff95fc8d72c4   17.35
# 306522      transaction  d1c4500ace2e45e9a45d3cd2fccac8d8    4.42
# 306523      transaction  b65affd9e07346a1906364a396950e3d   18.35
# 306524      transaction  d613ca9c59dd42f497bdbf6178da54a7   25.14
# 306525      transaction  eec70ab28af74a22a4aeb889c0317944   43.58
# 306526      transaction  24f56b5e1849462093931b164eb803b5   22.64
# 306527  offer completed  24f56b5e1849462093931b164eb803b5     NaN
# 306528      transaction  5ca2620962114246ab218fc648eb3934    2.20
# 306529      transaction  b3a1272bc9904337b331bf348c3e8c17    1.59
# 306530      transaction  68213b08d99a4ae1b0dcb72aebd9aa35    9.53
# 306531      transaction  a00058cf10334a308c68e7631c529907    3.61
# 306532      transaction  76ddbd6576844afe811f1a3c0fbb5bec    3.53
# 306533      transaction  c02b10e8752c4d8e9b73f918558531f7    4.05
#
#                                 offer_id  reward  time_days
# 0       9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN       0.00
# 1       0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN       0.00
# 2       2906b810c7d4411798c6938adc9daaa5     NaN       0.00
# 3       fafdcd668e3743c1bb461111dcafc2a4     NaN       0.00
# 4       4d5c57ea9a6940dd891ad53e9dbe8da0     NaN       0.00
# 5       f19421c1d4aa40978ebb69ca19b0e20d     NaN       0.00
# 6       2298d6c36e964ae4a3e7e9706d1fb8c2     NaN       0.00
# 7       3f207df678b143eea3cee63160fa8bed     NaN       0.00
# 8       0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN       0.00
# 9       0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN       0.00
# 10      0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN       0.00
# 11      0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN       0.00
# 12      ae264e3637204a6fb9bb56bc8210ddfd     NaN       0.00
# 13      3f207df678b143eea3cee63160fa8bed     NaN       0.00
# 14      0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN       0.00
# 15      fafdcd668e3743c1bb461111dcafc2a4     NaN       0.00
# 16      0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN       0.00
# 17      2906b810c7d4411798c6938adc9daaa5     NaN       0.00
# 18      9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN       0.00
# 19      ae264e3637204a6fb9bb56bc8210ddfd     NaN       0.00
# 20      2906b810c7d4411798c6938adc9daaa5     NaN       0.00
# 21      9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN       0.00
# 22      4d5c57ea9a6940dd891ad53e9dbe8da0     NaN       0.00
# 23      2906b810c7d4411798c6938adc9daaa5     NaN       0.00
# 24      2298d6c36e964ae4a3e7e9706d1fb8c2     NaN       0.00
# 25      2906b810c7d4411798c6938adc9daaa5     NaN       0.00
# 26      f19421c1d4aa40978ebb69ca19b0e20d     NaN       0.00
# 27      ae264e3637204a6fb9bb56bc8210ddfd     NaN       0.00
# 28      9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN       0.00
# 29      fafdcd668e3743c1bb461111dcafc2a4     NaN       0.00
# ...                                  ...     ...        ...
# 306504                               NaN     NaN      29.75
# 306505                               NaN     NaN      29.75
# 306506  fafdcd668e3743c1bb461111dcafc2a4     2.0      29.75
# 306507  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN      29.75
# 306508                               NaN     NaN      29.75
# 306509  fafdcd668e3743c1bb461111dcafc2a4     2.0      29.75
# 306510                               NaN     NaN      29.75
# 306511                               NaN     NaN      29.75
# 306512                               NaN     NaN      29.75
# 306513                               NaN     NaN      29.75
# 306514                               NaN     NaN      29.75
# 306515                               NaN     NaN      29.75
# 306516                               NaN     NaN      29.75
# 306517                               NaN     NaN      29.75
# 306518                               NaN     NaN      29.75
# 306519                               NaN     NaN      29.75
# 306520                               NaN     NaN      29.75
# 306521                               NaN     NaN      29.75
# 306522                               NaN     NaN      29.75
# 306523                               NaN     NaN      29.75
# 306524                               NaN     NaN      29.75
# 306525                               NaN     NaN      29.75
# 306526                               NaN     NaN      29.75
# 306527  fafdcd668e3743c1bb461111dcafc2a4     2.0      29.75
# 306528                               NaN     NaN      29.75
# 306529                               NaN     NaN      29.75
# 306530                               NaN     NaN      29.75
# 306531                               NaN     NaN      29.75
# 306532                               NaN     NaN      29.75
# 306533                               NaN     NaN      29.75
#
# [306534 rows x 6 columns]

# %%
transcript[transcript.event == 'offer received']
# Out:
#                  event                       customer_id  amount  \
# 0       offer received  78afa995795e4d85b5d9ceeca43f5fef     NaN
# 1       offer received  a03223e636434f42ac4c3df47e8bac43     NaN
# 2       offer received  e2127556f4f64592b11af22de27a7932     NaN
# 3       offer received  8ec6ce2a7e7949b1bf142def7d0e0586     NaN
# 4       offer received  68617ca6246f4fbc85e91a2a49552598     NaN
# 5       offer received  389bc3fa690240e798340f5a15918d5c     NaN
# 6       offer received  c4863c7985cf408faee930f111475da3     NaN
# 7       offer received  2eeac8d8feae4a8cad5a6af0499a211d     NaN
# 8       offer received  aa4862eba776480b8bb9c68455b8c2e1     NaN
# 9       offer received  31dda685af34476cad5bc968bdb01c53     NaN
# 10      offer received  744d603ef08c4f33af5a61c8c7628d1c     NaN
# 11      offer received  3d02345581554e81b7b289ab5e288078     NaN
# 12      offer received  4b0da7e80e5945209a1fdddfe813dbe0     NaN
# 13      offer received  c27e0d6ab72c455a8bb66d980963de60     NaN
# 14      offer received  d53717f5400c4e84affdaeda9dd926b3     NaN
# 15      offer received  f806632c011441378d4646567f357a21     NaN
# 16      offer received  d058f73bf8674a26a95227db098147b1     NaN
# 17      offer received  65aba5c617294649aeb624da249e1ee5     NaN
# 18      offer received  ebe7ef46ea6f4963a7dd49f501b26779     NaN
# 19      offer received  1e9420836d554513ab90eba98552d0a9     NaN
# 20      offer received  868317b9be554cb18e50bc68484749a2     NaN
# 21      offer received  f082d80f0aac47a99173ba8ef8fc1909     NaN
# 22      offer received  102e9454054946fda62242d2e176fdce     NaN
# 23      offer received  4beeb3ed64dd4898b0edf2f6b67426d3     NaN
# 24      offer received  9f30b375d7bd4c62a884ffe7034e09ee     NaN
# 25      offer received  25c906289d154b66bf579693f89481c9     NaN
# 26      offer received  6e014185620b49bd98749f728747572f     NaN
# 27      offer received  02c083884c7d45b39cc68e1314fec56c     NaN
# 28      offer received  c0d210398dee4a0895b24444a5fcd1d2     NaN
# 29      offer received  8be4463721e14d7fa600686bf8c8b2ed     NaN
# ...                ...                               ...     ...
# 257857  offer received  752045b74388467d99a44eac9501116e     NaN
# 257858  offer received  e9d127cf3f794ccbaac940f93c15ce8c     NaN
# 257859  offer received  e340cbf00a914f0c958577c0af36ed8a     NaN
# 257860  offer received  10316535e185400fb093c371d62254e3     NaN
# 257861  offer received  cec1cdc6b77e41abbdce8903c5522e7e     NaN
# 257862  offer received  f19d9482309d4e93ad74935f9e46e44c     NaN
# 257863  offer received  a2e6029e17b6466187a40b66e333a73e     NaN
# 257864  offer received  6e71b66784844d1ab8376ac8ab096d4b     NaN
# 257865  offer received  3afe03f081f54aa5a0f3f526b76a1628     NaN
# 257866  offer received  122c0c2a3c2540848f8c3fdc37e97639     NaN
# 257867  offer received  eb7dd979f4644052a5c401a01f129132     NaN
# 257868  offer received  54bead4179c44b71acc4e8398181d183     NaN
# 257869  offer received  a00058cf10334a308c68e7631c529907     NaN
# 257870  offer received  5c686d09ca4d475a8f750f2ba07e0440     NaN
# 257871  offer received  1966fa40d2f84620b2b1b9b64f8e0209     NaN
# 257872  offer received  ff737c250d2343729ade04c4f6eb1001     NaN
# 257873  offer received  392d23b2c958493197f647bedfe4f418     NaN
# 257874  offer received  97ee6e7a12fe4064b260fa48bdd0330f     NaN
# 257875  offer received  bf3069b178fe40d789dd027901bc406b     NaN
# 257876  offer received  76ddbd6576844afe811f1a3c0fbb5bec     NaN
# 257877  offer received  f653cf2d8bba42d0a53c2937ee2e5893     NaN
# 257878  offer received  ca45ee1883624304bac1e4c8a114f045     NaN
# 257879  offer received  670626b55bfb4ba39c85b27cc7cca527     NaN
# 257880  offer received  f924927e7f844ecebf87eef93f4d2688     NaN
# 257881  offer received  a57890c3bbb7463e9018abb7fecadb15     NaN
# 257882  offer received  d087c473b4d247ccb0abfef59ba12b0e     NaN
# 257883  offer received  cb23b66c56f64b109d673d5e56574529     NaN
# 257884  offer received  6d5f3a774f3d4714ab0c092238f3a1d7     NaN
# 257885  offer received  9dc1421481194dcd9400aec7c9ae6366     NaN
# 257886  offer received  e4052622e5ba45a8b96b59aba68cf068     NaN
#
#                                 offer_id  reward  time_days
# 0       9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN        0.0
# 1       0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN        0.0
# 2       2906b810c7d4411798c6938adc9daaa5     NaN        0.0
# 3       fafdcd668e3743c1bb461111dcafc2a4     NaN        0.0
# 4       4d5c57ea9a6940dd891ad53e9dbe8da0     NaN        0.0
# 5       f19421c1d4aa40978ebb69ca19b0e20d     NaN        0.0
# 6       2298d6c36e964ae4a3e7e9706d1fb8c2     NaN        0.0
# 7       3f207df678b143eea3cee63160fa8bed     NaN        0.0
# 8       0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN        0.0
# 9       0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN        0.0
# 10      0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN        0.0
# 11      0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN        0.0
# 12      ae264e3637204a6fb9bb56bc8210ddfd     NaN        0.0
# 13      3f207df678b143eea3cee63160fa8bed     NaN        0.0
# 14      0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN        0.0
# 15      fafdcd668e3743c1bb461111dcafc2a4     NaN        0.0
# 16      0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN        0.0
# 17      2906b810c7d4411798c6938adc9daaa5     NaN        0.0
# 18      9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN        0.0
# 19      ae264e3637204a6fb9bb56bc8210ddfd     NaN        0.0
# 20      2906b810c7d4411798c6938adc9daaa5     NaN        0.0
# 21      9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN        0.0
# 22      4d5c57ea9a6940dd891ad53e9dbe8da0     NaN        0.0
# 23      2906b810c7d4411798c6938adc9daaa5     NaN        0.0
# 24      2298d6c36e964ae4a3e7e9706d1fb8c2     NaN        0.0
# 25      2906b810c7d4411798c6938adc9daaa5     NaN        0.0
# 26      f19421c1d4aa40978ebb69ca19b0e20d     NaN        0.0
# 27      ae264e3637204a6fb9bb56bc8210ddfd     NaN        0.0
# 28      9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN        0.0
# 29      fafdcd668e3743c1bb461111dcafc2a4     NaN        0.0
# ...                                  ...     ...        ...
# 257857  3f207df678b143eea3cee63160fa8bed     NaN       24.0
# 257858  3f207df678b143eea3cee63160fa8bed     NaN       24.0
# 257859  2906b810c7d4411798c6938adc9daaa5     NaN       24.0
# 257860  3f207df678b143eea3cee63160fa8bed     NaN       24.0
# 257861  fafdcd668e3743c1bb461111dcafc2a4     NaN       24.0
# 257862  fafdcd668e3743c1bb461111dcafc2a4     NaN       24.0
# 257863  2298d6c36e964ae4a3e7e9706d1fb8c2     NaN       24.0
# 257864  ae264e3637204a6fb9bb56bc8210ddfd     NaN       24.0
# 257865  4d5c57ea9a6940dd891ad53e9dbe8da0     NaN       24.0
# 257866  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN       24.0
# 257867  f19421c1d4aa40978ebb69ca19b0e20d     NaN       24.0
# 257868  2906b810c7d4411798c6938adc9daaa5     NaN       24.0
# 257869  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN       24.0
# 257870  2906b810c7d4411798c6938adc9daaa5     NaN       24.0
# 257871  f19421c1d4aa40978ebb69ca19b0e20d     NaN       24.0
# 257872  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN       24.0
# 257873  ae264e3637204a6fb9bb56bc8210ddfd     NaN       24.0
# 257874  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN       24.0
# 257875  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN       24.0
# 257876  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN       24.0
# 257877  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN       24.0
# 257878  3f207df678b143eea3cee63160fa8bed     NaN       24.0
# 257879  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN       24.0
# 257880  5a8bc65990b245e5a138643cd4eb9837     NaN       24.0
# 257881  5a8bc65990b245e5a138643cd4eb9837     NaN       24.0
# 257882  ae264e3637204a6fb9bb56bc8210ddfd     NaN       24.0
# 257883  2906b810c7d4411798c6938adc9daaa5     NaN       24.0
# 257884  2298d6c36e964ae4a3e7e9706d1fb8c2     NaN       24.0
# 257885  ae264e3637204a6fb9bb56bc8210ddfd     NaN       24.0
# 257886  3f207df678b143eea3cee63160fa8bed     NaN       24.0
#
# [76277 rows x 6 columns]

# %%
# View examples of a randomly chosen customer
transcript[transcript.customer_id	 == 'bb0f25e23a4c4de6a645527c275cd594']
# Out:
#                   event                       customer_id  amount  \
# 317      offer received  bb0f25e23a4c4de6a645527c275cd594     NaN
# 12720       transaction  bb0f25e23a4c4de6a645527c275cd594   28.08
# 12721   offer completed  bb0f25e23a4c4de6a645527c275cd594     NaN
# 40812      offer viewed  bb0f25e23a4c4de6a645527c275cd594     NaN
# 52288       transaction  bb0f25e23a4c4de6a645527c275cd594   21.62
# 53492    offer received  bb0f25e23a4c4de6a645527c275cd594     NaN
# 74855      offer viewed  bb0f25e23a4c4de6a645527c275cd594     NaN
# 97732       transaction  bb0f25e23a4c4de6a645527c275cd594   35.95
# 97733   offer completed  bb0f25e23a4c4de6a645527c275cd594     NaN
# 150932   offer received  bb0f25e23a4c4de6a645527c275cd594     NaN
# 163478     offer viewed  bb0f25e23a4c4de6a645527c275cd594     NaN
# 184965      transaction  bb0f25e23a4c4de6a645527c275cd594   25.18
# 184966  offer completed  bb0f25e23a4c4de6a645527c275cd594     NaN
# 193250      transaction  bb0f25e23a4c4de6a645527c275cd594   24.40
# 201883   offer received  bb0f25e23a4c4de6a645527c275cd594     NaN
# 221968     offer viewed  bb0f25e23a4c4de6a645527c275cd594     NaN
# 232934      transaction  bb0f25e23a4c4de6a645527c275cd594   19.46
# 232935  offer completed  bb0f25e23a4c4de6a645527c275cd594     NaN
# 245438   offer received  bb0f25e23a4c4de6a645527c275cd594     NaN
# 262223     offer viewed  bb0f25e23a4c4de6a645527c275cd594     NaN
# 291554      transaction  bb0f25e23a4c4de6a645527c275cd594   17.25
# 291555  offer completed  bb0f25e23a4c4de6a645527c275cd594     NaN
# 300686      transaction  bb0f25e23a4c4de6a645527c275cd594   16.96
#
#                                 offer_id  reward  time_days
# 317     2298d6c36e964ae4a3e7e9706d1fb8c2     NaN       0.00
# 12720                                NaN     NaN       0.00
# 12721   2298d6c36e964ae4a3e7e9706d1fb8c2     3.0       0.00
# 40812   2298d6c36e964ae4a3e7e9706d1fb8c2     NaN       4.00
# 52288                                NaN     NaN       6.75
# 53492   9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN       7.00
# 74855   9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN       7.75
# 97732                                NaN     NaN      11.00
# 97733   9b98b8c7a33c4b65b9aebfe6a799e6d9     5.0      11.00
# 150932  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN      17.00
# 163478  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN      17.00
# 184965                               NaN     NaN      18.75
# 184966  0b1e1539f2cc45b7b9fa7c272da2e1d7     5.0      18.75
# 193250                               NaN     NaN      19.75
# 201883  ae264e3637204a6fb9bb56bc8210ddfd     NaN      21.00
# 221968  ae264e3637204a6fb9bb56bc8210ddfd     NaN      21.50
# 232934                               NaN     NaN      22.50
# 232935  ae264e3637204a6fb9bb56bc8210ddfd    10.0      22.50
# 245438  2298d6c36e964ae4a3e7e9706d1fb8c2     NaN      24.00
# 262223  2298d6c36e964ae4a3e7e9706d1fb8c2     NaN      24.25
# 291554                               NaN     NaN      27.25
# 291555  2298d6c36e964ae4a3e7e9706d1fb8c2     3.0      27.25
# 300686                               NaN     NaN      28.75

# %% [markdown]
# . For each customer in the profile data set, get all transactions
# . For each ‘offer received’, see whether offer is viewed (# of times viewed) and whether it is completed within the offer time period
#     . Get all of events that match the customer_id & offer_id for that received offer
#     . Get offer duration time and determine times that offer is valid
# . Sum the amount spent during the offer period

# %%
# Loop through each person to calulate the frequency of 'offer viewed' and 'offer completed' combinations. 
# Also keep track of transactions that occur without an offer received

# Calculate boolean masks of the indices which contain 'offer received', 'offer viewed', and 'offer completed' values:
received_mask = (transcript.event == 'offer received')
viewed_mask = (transcript.event == 'offer viewed')
completed_mask = (transcript.event == 'offer completed')
tranaction_mask = (transcript.event == 'transaction')

a = profile[profile.id == 'bb0f25e23a4c4de6a645527c275cd594'].index
#a = profile[profile.id == '78afa995795e4d85b5d9ceeca43f5fef'].index

if 'offer_completed' not in transcript.columns:
  transcript.insert(loc=len(transcript.columns), column='offer_completed', value=np.zeros_like(transcript.index))

if 'offer_viewed' not in transcript.columns:
  transcript.insert(loc=len(transcript.columns), column='offer_viewed', value=np.zeros_like(transcript.index))

if 'offer_compViewed' not in transcript.columns:
  transcript.insert(loc=len(transcript.columns), column='offer_compViewed', value=np.zeros_like(transcript.index))

if 'offer_compNotViewed' not in transcript.columns:
  transcript.insert(loc=len(transcript.columns), column='offer_compNotViewed', value=np.zeros_like(transcript.index))

if 'compTransAmt' not in transcript.columns:
  transcript.insert(loc=len(transcript.columns), column='compTransAmt', value=np.zeros_like(transcript.index))

if 'rewardReceived' not in transcript.columns:
  transcript.insert(loc=len(transcript.columns), column='rewardReceived', value=np.zeros_like(transcript.index))

if 'adjRev' not in transcript.columns:
  transcript.insert(loc=len(transcript.columns), column='adjRev', value=np.zeros_like(transcript.index))

if 'offerTrans' not in transcript.columns:
  transcript.insert(loc=len(transcript.columns), column='offerTrans', value=np.zeros_like(transcript.index))

# Create a dictionary of 'offer_id' and offer durations
offerDurations = dict(zip(portfolio.id,portfolio.duration))

for i in profile.index:
  #print('i:',i)

  person = profile.id[i]
  person_mask = (transcript.customer_id == person)  

  received_indices = transcript.index[person_mask & received_mask]
  viewed_indices = transcript.index[person_mask & viewed_mask]
  completed_indices = transcript.index[person_mask & completed_mask]
  transaction_indices = transcript.index[person_mask & tranaction_mask]

  # checking for received offers and their times
  received_ids = transcript.offer_id[received_indices].values
  received_times = transcript.time_days[received_indices].values

  # Get the duration of each offer
  duration_times = [offerDurations[x] for x in received_ids]
  receivedEnd_times = received_times + duration_times

  #print('Received:')
  #print('Received ids:',received_ids)
  #print('Received times:',received_times)
  #print('Received durations:',duration_times)
  #print('Received end times:',receivedEnd_times)

  # checking for completed offers whether they were completed before or after they were viewed:
  viewed_ids = transcript.offer_id[viewed_indices].values
  viewed_times = transcript.time_days[viewed_indices].values

  #print('Viewed:')
  #print(viewed_ids)
  #print(viewed_times)

  completed_ids = transcript.offer_id[completed_indices].values
  completed_times = transcript.time_days[completed_indices].values
  completed_rewards = transcript.reward[completed_indices].values

  #print('Completed:')
  #print(completed_ids)
  #print(completed_times)
  #print(completed_rewards)

  transaction_amounts = transcript.amount[transaction_indices].values
  transaction_times = transcript.time_days[transaction_indices].values

  #print('Transactions:')
  #print(transaction_amounts)
  #print(transaction_times)

  for j, recId in enumerate(received_ids):

    # Get the duration, begin time, and end time of current offer
    offerBegin = received_times[j]
    offerEnd = receivedEnd_times[j]
    
    # Create a time mask for current offer
    #timeBegin_mask = (transcript[person_mask].time_days >= offerBegin)
    #timeEnd_mask = (transcript[person_mask].time_days < offerEnd)
    #time_mask = (timeBegin_mask & timeEnd_mask)
    #timeOffer_mask = offer_mask & time_mask

    # Create offer mask for current offer
    #offer_mask = (transcript[person_mask].offer_id == recId) 
    #personOffer_mask = time_mask # (offer_mask & person_mask)

    # Get sum of transaction ammount during offer period
    offerTrans_mask = (transaction_times >= offerBegin) & (transaction_times <= offerEnd)
    #offerTrans = transaction_amounts[offerTrans_mask]
    #offerTransSum = sum(compTrans)
    transcript.iloc[[received_indices[j]],13] = sum(transaction_amounts[offerTrans_mask])

    # Check to see whether an offer was viewed
    if (recId in viewed_ids):
      view_mask = (viewed_ids == recId) & (viewed_times >= offerBegin) & (viewed_times <= offerEnd)
      offerViews = sum(view_mask)
      if offerViews > 0:
        transcript.iloc[[received_indices[j]],7] = 1

    # Check to see whether an offer was completed
    if (recId in completed_ids):
      #print(recId)

      # Match the recId to the completed offer
      compOffer_mask = (completed_ids == recId) & (completed_times >= offerBegin) & (completed_times <= offerEnd)
      #print('completed_rewards',completed_rewards)
      #print(completed_rewards[compOffer_mask])
      #print('Completed times:',completed_times[compOffer_mask][0])
      #print('Completed rewards:',completed_rewards[compOffer_mask][0])

      #print('sum(compOffer_mask)',sum(compOffer_mask))

      # Match the recId to the completed offer
      compOffer_mask = (completed_ids == recId) & (completed_times >= offerBegin) & (completed_times <= offerEnd)

      # If an offer was completed
      if sum(compOffer_mask) > 0:
        # Get reward ammount and time for completed offer
        compOfferReward = completed_rewards[compOffer_mask][0]
        compOfferTime = completed_times[compOffer_mask][0]

        # Mark the the received offer was completed in the transcript data set
        transcript.iloc[[received_indices[j]],6] = 1

        # Record reward of completed offer
        transcript.iloc[[received_indices[j]],11] = compOfferReward

        # Get sum of transaction ammount during completed offer period
        compTrans_mask = (transaction_times >= offerBegin) & (transaction_times <= compOfferTime)
        compTrans = transaction_amounts[compTrans_mask]
        compTransSum = sum(compTrans)

        ## Update transcript table
        transcript.iloc[[received_indices[j]],10] = compTransSum
        transcript.iloc[[received_indices[j]],12] = compTransSum - compOfferReward

        # Check to see whether an offer was viewed and viewed before completed
        if (recId in viewed_ids):
          compView_mask = (viewed_ids == recId) & (viewed_times >= offerBegin) & (viewed_times <= compOfferTime)
          compView = sum(compView_mask)
          #print(compView_mask)
          if compView > 0:
            transcript.iloc[[received_indices[j]],8] = sum(compView_mask)
            #print('Offer viewed and then completed')
          else:
            transcript.iloc[[received_indices[j]],9] = 1
        else:
          # Offer completed, but not viewed
          transcript.iloc[[received_indices[j]],9] = 1

  #printing progress:
  if (i%100 == 0):
    print('{} out of {} is done'.format(i, len(profile.index)))
# Out:
# 0 out of 17000 is done
# 100 out of 17000 is done
# 200 out of 17000 is done
# 300 out of 17000 is done
# 400 out of 17000 is done
# 500 out of 17000 is done
# 600 out of 17000 is done
# 700 out of 17000 is done
# 800 out of 17000 is done
# 900 out of 17000 is done
# 1000 out of 17000 is done
# 1100 out of 17000 is done
# 1200 out of 17000 is done
# 1300 out of 17000 is done
# 1400 out of 17000 is done
# 1500 out of 17000 is done
# 1600 out of 17000 is done
# 1700 out of 17000 is done
# 1800 out of 17000 is done
# 1900 out of 17000 is done
# 2000 out of 17000 is done
# 2100 out of 17000 is done
# 2200 out of 17000 is done
# 2300 out of 17000 is done
# 2400 out of 17000 is done
# 2500 out of 17000 is done
# 2600 out of 17000 is done
# 2700 out of 17000 is done
# 2800 out of 17000 is done
# 2900 out of 17000 is done
# 3000 out of 17000 is done
# 3100 out of 17000 is done
# 3200 out of 17000 is done
# 3300 out of 17000 is done
# 3400 out of 17000 is done
# 3500 out of 17000 is done
# 3600 out of 17000 is done
# 3700 out of 17000 is done
# 3800 out of 17000 is done
# 3900 out of 17000 is done
# 4000 out of 17000 is done
# 4100 out of 17000 is done
# 4200 out of 17000 is done
# 4300 out of 17000 is done
# 4400 out of 17000 is done
# 4500 out of 17000 is done
# 4600 out of 17000 is done
# 4700 out of 17000 is done
# 4800 out of 17000 is done
# 4900 out of 17000 is done
# 5000 out of 17000 is done
# 5100 out of 17000 is done
# 5200 out of 17000 is done
# 5300 out of 17000 is done
# 5400 out of 17000 is done
# 5500 out of 17000 is done
# 5600 out of 17000 is done
# 5700 out of 17000 is done
# 5800 out of 17000 is done
# 5900 out of 17000 is done
# 6000 out of 17000 is done
# 6100 out of 17000 is done
# 6200 out of 17000 is done
# 6300 out of 17000 is done
# 6400 out of 17000 is done
# 6500 out of 17000 is done
# 6600 out of 17000 is done
# 6700 out of 17000 is done
# 6800 out of 17000 is done
# 6900 out of 17000 is done
# 7000 out of 17000 is done
# 7100 out of 17000 is done
# 7200 out of 17000 is done
# 7300 out of 17000 is done
# 7400 out of 17000 is done
# 7500 out of 17000 is done
# 7600 out of 17000 is done
# 7700 out of 17000 is done
# 7800 out of 17000 is done
# 7900 out of 17000 is done
# 8000 out of 17000 is done
# 8100 out of 17000 is done
# 8200 out of 17000 is done
# 8300 out of 17000 is done
# 8400 out of 17000 is done
# 8500 out of 17000 is done
# 8600 out of 17000 is done
# 8700 out of 17000 is done
# 8800 out of 17000 is done
# 8900 out of 17000 is done
# 9000 out of 17000 is done
# 9100 out of 17000 is done
# 9200 out of 17000 is done
# 9300 out of 17000 is done
# 9400 out of 17000 is done
# 9500 out of 17000 is done
# 9600 out of 17000 is done
# 9700 out of 17000 is done
# 9800 out of 17000 is done
# 9900 out of 17000 is done
# 10000 out of 17000 is done
# 10100 out of 17000 is done
# 10200 out of 17000 is done
# 10300 out of 17000 is done
# 10400 out of 17000 is done
# 10500 out of 17000 is done
# 10600 out of 17000 is done
# 10700 out of 17000 is done
# 10800 out of 17000 is done
# 10900 out of 17000 is done
# 11000 out of 17000 is done
# 11100 out of 17000 is done
# 11200 out of 17000 is done
# 11300 out of 17000 is done
# 11400 out of 17000 is done
# 11500 out of 17000 is done
# 11600 out of 17000 is done
# 11700 out of 17000 is done
# 11800 out of 17000 is done
# 11900 out of 17000 is done
# 12000 out of 17000 is done
# 12100 out of 17000 is done
# 12200 out of 17000 is done
# 12300 out of 17000 is done
# 12400 out of 17000 is done
# 12500 out of 17000 is done
# 12600 out of 17000 is done
# 12700 out of 17000 is done
# 12800 out of 17000 is done
# 12900 out of 17000 is done
# 13000 out of 17000 is done
# 13100 out of 17000 is done
# 13200 out of 17000 is done
# 13300 out of 17000 is done
# 13400 out of 17000 is done
# 13500 out of 17000 is done
# 13600 out of 17000 is done
# 13700 out of 17000 is done
# 13800 out of 17000 is done
# 13900 out of 17000 is done
# 14000 out of 17000 is done
# 14100 out of 17000 is done
# 14200 out of 17000 is done
# 14300 out of 17000 is done
# 14400 out of 17000 is done
# 14500 out of 17000 is done
# 14600 out of 17000 is done
# 14700 out of 17000 is done
# 14800 out of 17000 is done
# 14900 out of 17000 is done
# 15000 out of 17000 is done
# 15100 out of 17000 is done
# 15200 out of 17000 is done
# 15300 out of 17000 is done
# 15400 out of 17000 is done
# 15500 out of 17000 is done
# 15600 out of 17000 is done
# 15700 out of 17000 is done
# 15800 out of 17000 is done
# 15900 out of 17000 is done
# 16000 out of 17000 is done
# 16100 out of 17000 is done
# 16200 out of 17000 is done
# 16300 out of 17000 is done
# 16400 out of 17000 is done
# 16500 out of 17000 is done
# 16600 out of 17000 is done
# 16700 out of 17000 is done
# 16800 out of 17000 is done
# 16900 out of 17000 is done

# %%
transcript[person_mask].head(20)
# Out:
#                   event                       customer_id  amount  \
# 12649    offer received  e4052622e5ba45a8b96b59aba68cf068     NaN
# 18066      offer viewed  e4052622e5ba45a8b96b59aba68cf068     NaN
# 32623       transaction  e4052622e5ba45a8b96b59aba68cf068   21.55
# 32624   offer completed  e4052622e5ba45a8b96b59aba68cf068     NaN
# 39543       transaction  e4052622e5ba45a8b96b59aba68cf068   25.19
# 42026       transaction  e4052622e5ba45a8b96b59aba68cf068   21.53
# 123538   offer received  e4052622e5ba45a8b96b59aba68cf068     NaN
# 163373   offer received  e4052622e5ba45a8b96b59aba68cf068     NaN
# 196833      transaction  e4052622e5ba45a8b96b59aba68cf068   30.57
# 196834  offer completed  e4052622e5ba45a8b96b59aba68cf068     NaN
# 198464      transaction  e4052622e5ba45a8b96b59aba68cf068   19.47
# 237363     offer viewed  e4052622e5ba45a8b96b59aba68cf068     NaN
# 257886   offer received  e4052622e5ba45a8b96b59aba68cf068     NaN
# 301914      transaction  e4052622e5ba45a8b96b59aba68cf068   24.71
#
#                                 offer_id  reward  time_days  offer_completed  \
# 12649   2298d6c36e964ae4a3e7e9706d1fb8c2     NaN       0.00                1
# 18066   2298d6c36e964ae4a3e7e9706d1fb8c2     NaN       0.25                0
# 32623                                NaN     NaN       2.25                0
# 32624   2298d6c36e964ae4a3e7e9706d1fb8c2     3.0       2.25                0
# 39543                                NaN     NaN       3.50                0
# 42026                                NaN     NaN       4.00                0
# 123538  3f207df678b143eea3cee63160fa8bed     NaN      14.00                0
# 163373  f19421c1d4aa40978ebb69ca19b0e20d     NaN      17.00                1
# 196833                               NaN     NaN      20.00                0
# 196834  f19421c1d4aa40978ebb69ca19b0e20d     5.0      20.00                0
# 198464                               NaN     NaN      20.25                0
# 237363  f19421c1d4aa40978ebb69ca19b0e20d     NaN      22.75                0
# 257886  3f207df678b143eea3cee63160fa8bed     NaN      24.00                0
# 301914                               NaN     NaN      28.75                0
#
#         offer_viewed  offer_compViewed  offer_compNotViewed  compTransAmt  \
# 12649              1                 1                    0         21.55
# 18066              0                 0                    0          0.00
# 32623              0                 0                    0          0.00
# 32624              0                 0                    0          0.00
# 39543              0                 0                    0          0.00
# 42026              0                 0                    0          0.00
# 123538             0                 0                    0          0.00
# 163373             0                 0                    1         30.57
# 196833             0                 0                    0          0.00
# 196834             0                 0                    0          0.00
# 198464             0                 0                    0          0.00
# 237363             0                 0                    0          0.00
# 257886             0                 0                    0          0.00
# 301914             0                 0                    0          0.00
#
#         rewardReceived  adjRev  offerTrans
# 12649              3.0   18.55       68.27
# 18066              0.0    0.00        0.00
# 32623              0.0    0.00        0.00
# 32624              0.0    0.00        0.00
# 39543              0.0    0.00        0.00
# 42026              0.0    0.00        0.00
# 123538             0.0    0.00        0.00
# 163373             5.0   25.57       50.04
# 196833             0.0    0.00        0.00
# 196834             0.0    0.00        0.00
# 198464             0.0    0.00        0.00
# 237363             0.0    0.00        0.00
# 257886             0.0    0.00        0.00
# 301914             0.0    0.00        0.00

# %%
# Get indices of completed offers
offerCompIdx = transcript[transcript.event == 'offer completed'].index.tolist()
  
# Statistics describing the reward amounts
transcript.iloc[offerCompIdx].reward.describe()
# Out:
# count    33579.000000
# mean         4.904137
# std          2.886647
# min          2.000000
# 25%          2.000000
# 50%          5.000000
# 75%          5.000000
# max         10.000000
# Name: reward, dtype: float64

# %%
fig = plt.figure()
ax = transcript.iloc[offerCompIdx].reward.plot.hist(bins=20)
plt.xlabel('Reward Amount ($)')
plt.ylabel('Frequency')
plt.title('Frequency of Reward Amounts')
# Out:
# Text(0.5,1,'Frequency of Reward Amounts')

# %%
transcript.to_pickle("./dummy_v2.pkl")

# %%
transcriptTransformRec = transcript[transcript.event == 'offer received']
